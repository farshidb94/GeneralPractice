# %% [markdown]
# <a href="https://colab.research.google.com/github/farshidb94/GeneralPractice/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import math

def dotproduct (list1, list2):
  lista = np.array(list1)
  listb = np.array(list2)
  if isinstance(lista, np.ndarray) and isinstance(listb, np.ndarray):
      if len(list1) == len(list2):
        return lista[0] * listb[0] + lista[1] * listb[1]
      else: raise Exception ('erorr')

print (dotproduct([1,2], [3,4]))
# Out:
# 11

# %%
lambda_value = 10
i = 1
count = 0
while i > np.exp(-lambda_value):
  i *= np.random.rand()
  count += 1
print(count)
# Out:
# 12

# %%
import time
time.perf_counter()
# Out:
# <function time.perf_counter>

# %%
def funfun(x,y):
  z = int(x) * int(y)
  return z

print(funfun('2',3))

z = 5
z.isnumeric()
# Out:
# 6
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-19-1270089031.py in <cell line: 0>()
#       6
#       7 z = 5
# ----> 8 z.isnumeric()
#
# AttributeError: 'int' object has no attribute 'isnumeric'

# %%
new = ['far', 'shi', 'dude']
old = [5,6,9]
print( dict(zip( new,old )) )
# Out:
# {'far': 5, 'shi': 6, 'dude': 9}

# %%
newlist = ['']*10

for i in range(10):
  if i%2==1:
    newlist[i] = 'odd'
  else:
    newlist[i] = i

newlist
# Out:
# [0, 'odd', 2, 'odd', 4, 'odd', 6, 'odd', 8, 'odd']

# %%
newlist = ['']*10
['odd' if i%2==1 else i for i in range(10) ]
# Out:
# [0, 'odd', 2, 'odd', 4, 'odd', 6, 'odd', 8, 'odd']

# %%
import numpy as np
x1 = np.linspace (-3,3,11)
y1 = x1**2

print(x1)
print(y1)
# Out:
# [-3.  -2.4 -1.8 -1.2 -0.6  0.   0.6  1.2  1.8  2.4  3. ]
# [9.   5.76 3.24 1.44 0.36 0.   0.36 1.44 3.24 5.76 9.  ]

# %%
import numpy as np

v = list(range(9))
m = np.reshape(v,(3,3))
c = 3*list(m)
v = np.array(v).reshape(9,1)

c*v
# Out:
# array([[ 0,  0,  0],
#        [ 3,  4,  5],
#        [12, 14, 16],
#        [ 0,  3,  6],
#        [12, 16, 20],
#        [30, 35, 40],
#        [ 0,  6, 12],
#        [21, 28, 35],
#        [48, 56, 64]])

# %%
import numpy as np
import pandas as pd
import string


for i, letter in zip(range(1,27),list(string.ascii_lowercase)):

  print('%g th letter is %s' %(i,letter))
# Out:
# 1 th letter is a
# 2 th letter is b
# 3 th letter is c
# 4 th letter is d
# 5 th letter is e
# 6 th letter is f
# 7 th letter is g
# 8 th letter is h
# 9 th letter is i
# 10 th letter is j
# 11 th letter is k
# 12 th letter is l
# 13 th letter is m
# 14 th letter is n
# 15 th letter is o
# 16 th letter is p
# 17 th letter is q
# 18 th letter is r
# 19 th letter is s
# 20 th letter is t
# 21 th letter is u
# 22 th letter is v
# 23 th letter is w
# 24 th letter is x
# 25 th letter is y
# 26 th letter is z

# %%
import matplotlib.pyplot as plt
#plt.plot([8,8], [1,8], 'm')
plt.plot([0,1], [1,8], 'g')
#plt.plot([1,1], [8,1], 'b')
plt.legend(['this is a test', 'this is anotha one'])
plt.show()

# %%
import matplotlib.pyplot as plt

# Top horizontal line (left to right)
plt.plot([0,0], [1,8], 'r', label='top line')

# Diagonal line (right to left)
plt.plot([0,1], [4,4], 'g', label='diagonal')

# Bottom horizontal line (left to right)
plt.plot([], [], 'b', label='bottom line')

# Show the legend
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(0,10,100)

for i in np.linspace(0,1,50):
  plt.plot (x, x**i, color=[0.5,i,0.34])

plt.show()

# %%
fig, ax = plt.subplots()
y = x**2
ax.plot(x,y, 'm-')
ax.annotate('here', (x[20],y[30]), arrowprops= dict(), xycoords='data', xytext=(5,5))
plt.show()

# %%
y = x**2 + np.cos(x)*10

#minpnt = np.argmin(y)
fig, ax = plt.subplots()
ax.plot(x,y, 'ko-', markersize = 15, markerfacecolor = 'teal')
ax.annotate(
    'min:', (x[4], y[0]),
            arrowprops={'arrowstyle':'wedge', 'color': 'm', 'lw' : 1.5},
            xycoords='data',
            xytext=(5,5) )
ax.set_ylabel('exercise')
plt.show()

# %%
import seaborn as ssn
import pandas as pd

n = 200
D = np.zeros((n,2))
D[:,0] = np.linspace(0,10, n) + np.random.rand(n)
D[:,1] = D[:,0] **2 + np.random.rand(n) *10

#ssn.jointplot(x = D[:,0], y = D[:,1])
#plt.show()

df = pd.DataFrame(data = D, columns = ['x', 'y'])
ssn.jointplot(data = df, x = 'x', y = 'y', kind = 'resid')
plt.show()
